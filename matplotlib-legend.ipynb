# %%
#legend
import matplotlib.pyplot as plt
import numpy as np
x=[12,28,43,36]
y1=[20,39,42,99]
y2=[30,49,58,66]
plt.plot(x,y1,label='1stone')
plt.plot(x,y2,label='2nd one')
plt.legend(loc='upper center',shadow=True,fancybox=True,facecolor='grey',edgecolor='black',framealpha=0.8)
